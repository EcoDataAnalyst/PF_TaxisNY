# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import calmap
import geopandas as gpd
import contextily as ctx

# %%
noise = pd.read_csv("datasets_pf_taxis/dataset_incidentes_ruido_2024.csv")

# %%
noise['Complaint Type'].unique()
# Out:
# array(['Noise - Residential', 'Noise - Street/Sidewalk',
#        'Noise - Commercial', 'Noise', 'Noise - Vehicle',
#        'Noise - Helicopter', 'Noise - House of Worship', 'Noise - Park'],
#       dtype=object)

# %%
noise['Descriptor'].unique()
# Out:
# array(['Loud Music/Party', 'Banging/Pounding', 'Loud Talking',
#        'Noise: air condition/ventilation equipment (NV1)',
#        'Noise: Alarms (NR3)', 'Car/Truck Music', 'Other', 'Engine Idling',
#        'Car/Truck Horn', 'NYPD', 'Loud Television',
#        'Noise: Construction Equipment (NC1)',
#        'Noise: Jack Hammering (NC2)', 'Noise, Barking Dog (NR5)',
#        'Noise: Construction Before/After Hours (NM1)',
#        'Noise:  lawn care equipment (NCL)',
#        'Noise: Private Carting Noise (NQ1)', 'News Gathering',
#        'Noise, Other Animals (NR6)',
#        'Noise: Other Noise Sources (Use Comments) (NZZ)',
#        'Noise: Manufacturing Noise (NK1)', 'Noise, Ice Cream Truck (NR4)',
#        'Noise: Boat(Engine,Music,Etc) (NR10)'], dtype=object)

# %%
noise = pd.read_csv("datasets_pf_taxis/dataset_incidentes_ruido_2024.csv")
# Filter noise Dataset with Complaint Type = Noise - Street/Sidewalk
noise = noise.loc[noise["Descriptor"] == "Engine Idling"]
noise.head()
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 367     59892075  01/01/2024 01:18:06 AM  01/01/2024 01:57:26 AM   NYPD
# 385     59891136  01/01/2024 01:20:44 AM  01/01/2024 01:38:08 AM   NYPD
# 429     59892985  01/01/2024 01:27:32 AM  01/01/2024 01:42:22 AM   NYPD
# 1202    59894106  01/01/2024 04:58:49 AM  01/01/2024 11:31:26 AM   NYPD
# 1350    59896576  01/01/2024 07:11:35 AM  01/01/2024 07:37:40 AM   NYPD
#
#                           Agency Name   Complaint Type     Descriptor  \
# 367   New York City Police Department  Noise - Vehicle  Engine Idling
# 385   New York City Police Department  Noise - Vehicle  Engine Idling
# 429   New York City Police Department  Noise - Vehicle  Engine Idling
# 1202  New York City Police Department  Noise - Vehicle  Engine Idling
# 1350  New York City Police Department  Noise - Vehicle  Engine Idling
#
#         Location Type  Incident Zip         Incident Address  ...  \
# 367   Street/Sidewalk       10453.0  2226 LORING PLACE NORTH  ...
# 385   Street/Sidewalk       10040.0     601 WEST  191 STREET  ...
# 429   Street/Sidewalk       11375.0    108-49 UNION TURNPIKE  ...
# 1202  Street/Sidewalk       11419.0         94-11 120 STREET  ...
# 1350  Street/Sidewalk       10465.0       2835 LAWTON AVENUE  ...
#
#      Vehicle Type Taxi Company Borough Taxi Pick Up Location  \
# 367           Van                  NaN                   NaN
# 385           Car                  NaN                   NaN
# 429           Car                  NaN                   NaN
# 1202          Car                  NaN                   NaN
# 1350          Car                  NaN                   NaN
#
#      Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 367                  NaN                      NaN       NaN
# 385                  NaN                      NaN       NaN
# 429                  NaN                      NaN       NaN
# 1202                 NaN                      NaN       NaN
# 1350                 NaN                      NaN       NaN
#
#      Bridge Highway Segment   Latitude  Longitude  \
# 367                     NaN  40.859817 -73.910016
# 385                     NaN  40.855642 -73.929351
# 429                     NaN  40.708615 -73.844744
# 1202                    NaN  40.693778 -73.826679
# 1350                    NaN  40.816966 -73.818631
#
#                                       Location
# 367   (40.859817364320826, -73.91001607319848)
# 385    (40.85564240936937, -73.92935055425096)
# 429    (40.70861452699336, -73.84474373676021)
# 1202   (40.69377795934481, -73.82667915975236)
# 1350   (40.81696644600334, -73.81863055708796)
#
# [5 rows x 41 columns]

# %%
noise.Descriptor.count()
# Out:
# 3427

# %%
# Sumar los duplicados por columna Created Date
noise.duplicated(subset=["Created Date"]).sum()
# Out:
# 0

# %%
# Eliminar filas con datos nulos en las columnas latitude y longitude
noise = noise.dropna(subset=["Latitude", "Longitude"])
noise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27634 entries, 2 to 198450
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      27634 non-null  int64
#  1   Created Date                    27634 non-null  object
#  2   Closed Date                     27601 non-null  object
#  3   Agency                          27634 non-null  object
#  4   Agency Name                     27634 non-null  object
#  5   Complaint Type                  27634 non-null  object
#  6   Descriptor                      27634 non-null  object
#  7   Location Type                   27634 non-null  object
#  8   Incident Zip                    27628 non-null  float64
#  9   Incident Address                27634 non-null  object
#  10  Street Name                     27634 non-null  object
#  11  Cross Street 1                  27607 non-null  object
#  12  Cross Street 2                  27575 non-null  object
#  13  Intersection Street 1           27607 non-null  object
#  14  Intersection Street 2           27575 non-null  object
#  15  Address Type                    27634 non-null  object
#  16  City                            25057 non-null  object
#  17  Landmark                        25057 non-null  object
#  18  Facility Type                   0 non-null      float64
#  19  Status                          27634 non-null  object
#  20  Due Date                        0 non-null      float64
#  21  Resolution Description          27601 non-null  object
#  22  Resolution Action Updated Date  27618 non-null  object
#  23  Community Board                 27634 non-null  object
#  24  BBL                             23821 non-null  float64
#  25  Borough                         27634 non-null  object
#  26  X Coordinate (State Plane)      27634 non-null  float64
#  27  Y Coordinate (State Plane)      27634 non-null  float64
#  28  Open Data Channel Type          27634 non-null  object
#  29  Park Facility Name              27634 non-null  object
#  30  Park Borough                    27634 non-null  object
#  31  Vehicle Type                    0 non-null      object
#  32  Taxi Company Borough            0 non-null      float64
#  33  Taxi Pick Up Location           0 non-null      float64
#  34  Bridge Highway Name             0 non-null      float64
#  35  Bridge Highway Direction        0 non-null      float64
#  36  Road Ramp                       0 non-null      float64
#  37  Bridge Highway Segment          0 non-null      float64
#  38  Latitude                        27634 non-null  float64
#  39  Longitude                       27634 non-null  float64
#  40  Location                        27634 non-null  object
# dtypes: float64(14), int64(1), object(26)
# memory usage: 8.9+ MB

# %%
# Resumen estadístico de las columnas categóricas
print(noise.describe(include=['object']))
# Out:
#                   Created Date             Closed Date Agency  \
# count                    27634                   27601  27634
# unique                   27541                   27380      1
# top     04/16/2024 09:04:24 PM  01/12/2024 03:31:47 AM   NYPD
# freq                         3                       3  27634
#
#                             Agency Name           Complaint Type  \
# count                             27634                    27634
# unique                                1                        1
# top     New York City Police Department  Noise - Street/Sidewalk
# freq                              27634                    27634
#
#               Descriptor    Location Type Incident Address Street Name  \
# count              27634            27634            27634       27634
# unique                 2                1            11609        2546
# top     Loud Music/Party  Street/Sidewalk    2400 7 AVENUE    7 AVENUE
# freq               18904            27634              840        1200
#
#           Cross Street 1  ...  Status  \
# count              27607  ...   27634
# unique              2449  ...       3
# top     WEST  140 STREET  ...  Closed
# freq                 842  ...   27599
#
#                                    Resolution Description  \
# count                                               27601
# unique                                                 12
# top     The Police Department responded to the complai...
# freq                                                10794
#
#        Resolution Action Updated Date Community Board    Borough  \
# count                           27618           27634      27634
# unique                          27210              72          6
# top            03/04/2024 03:01:46 AM    10 MANHATTAN  MANHATTAN
# freq                                6            2109      10856
#
#        Open Data Channel Type Park Facility Name Park Borough Vehicle Type  \
# count                   27634              27634        27634            0
# unique                      4                  1            6            0
# top                    MOBILE        Unspecified    MANHATTAN          NaN
# freq                    12554              27634        10856          NaN
#
#                                        Location
# count                                     27634
# unique                                    12111
# top     (40.81853515725049, -73.94135579635707)
# freq                                        840
#
# [4 rows x 26 columns]

# %%
# Convert 'Created Date' to datetime
noise['Created Date'] = pd.to_datetime(noise['Created Date'])
# Group data by Created date and count complaints
daily_complaints = noise.groupby(pd.Grouper(key="Created Date", freq="D")).size()
calmap.yearplot(daily_complaints, year=2024, cmap='YlGnBu')
# Out:
# C:\Users\rrobl\AppData\Local\Temp\ipykernel_35068\3274311230.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   noise['Created Date'] = pd.to_datetime(noise['Created Date'])
# <Axes: >

# %%
# Histogramas para las columnas numéricas 
noise.select_dtypes(include=np.number).hist(bins=50, figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
noise['Latitude'] = pd.to_numeric(noise['Latitude'])
# Repeat for 'Longitude' if necessary
noise['Longitude'] = pd.to_numeric(noise['Longitude'])

gdf = gpd.GeoDataFrame(
    noise, geometry=gpd.points_from_xy(noise.Longitude, noise.Latitude)
)

# Ensure 'Borough' column exists and contains valid borough names

# %%
boroughs = gdf["Borough"].unique()
borough_data = {borough: gdf[gdf["Borough"] == borough] for borough in boroughs}

# %%
for borough, data in borough_data.items():
    print(borough)
# Out:
# QUEENS
# BROOKLYN
# MANHATTAN
# STATEN ISLAND
# BRONX
# Unspecified

# %%
# Plot a google maps with seaborn
sns.set_style("whitegrid")
ax = gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor="grey")
ctx.add_basemap(ax, crs=gdf.crs.to_string())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       2 sns.set_style("whitegrid")
#       3 ax = gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor="grey")
# ----> 4 ctx.add_basemap(ax, crs=gdf.crs.to_string())
#
# AttributeError: 'NoneType' object has no attribute 'to_string'
